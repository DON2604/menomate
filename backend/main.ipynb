# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

initial_interaval=30

datas=pd.read_csv("prd.csv")

datas.head()

datas.loc[datas['mon'] == 'jan', 'int'] = 28

datas.to_csv('monthly_intervals.csv', index=False)
datas.head()
# Out:
#    mon  int
# 0  jan   28
# 1  feb   30
# 2  mar   30
# 3  apr   30
# 4  may   30
